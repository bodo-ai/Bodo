# %%
# Import all functions directly into the namespace for convenience
from snowflake_utils import (
    get_current_warehouse,
    get_snowflake_connection,
    get_table_column_types,
    get_table_info,
)

# %%
# Get a connection object
con = get_snowflake_connection(
    "creds.json", database="SNOWFLAKE_SAMPLE_DATA", warehouse="DEMO_WH"
)
# Out:
# /opt/anaconda3/envs/bodo_dev_310/lib/python3.10/site-packages/cryptography/hazmat/backends/openssl/x509.py:14: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   warnings.warn(

# %%
# Check and verify that we're using the correct warehouse
get_current_warehouse(con)
# Out:
# 'DEMO_WH'

# %%
# Visually inspect the query and find all the relevant tables
tables_to_check = [
    ("SNOWFLAKE_SAMPLE_DATA", "TPCH_SF1", "CUSTOMER"),
    ("SNOWFLAKE_SAMPLE_DATA", "TPCH_SF1", "LINEITEM"),
]

# %%
# For each table, get some basic information about the table. This will give information like
# the number of rows, etc.
for db, schema, table_name in tables_to_check:
    print(f"Getting information for {db}.{schema}.{table_name}")
    table_info = get_table_info(con, db, schema, table_name)
    display(table_info)
# Out:
# Getting information for SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.CUSTOMER
#            TABLE_CATALOG TABLE_SCHEMA TABLE_NAME TABLE_OWNER  TABLE_TYPE  \
# 0  SNOWFLAKE_SAMPLE_DATA     TPCH_SF1   CUSTOMER        None  BASE TABLE
#
#   IS_TRANSIENT CLUSTERING_KEY ROW_COUNT     BYTES RETENTION_TIME  ...  \
# 0           NO           None    150000  10747904              1  ...
#
#   USER_DEFINED_TYPE_CATALOG USER_DEFINED_TYPE_SCHEMA USER_DEFINED_TYPE_NAME  \
# 0                      None                     None                   None
#
#   IS_INSERTABLE_INTO IS_TYPED COMMIT_ACTION                          CREATED  \
# 0                YES      YES          None 2021-11-11 13:17:32.899000-08:00
#
#                       LAST_ALTERED AUTO_CLUSTERING_ON  \
# 0 2022-12-06 13:38:59.499000-08:00                 NO
#
#                              COMMENT
# 0  Customer data as defined by TPC-H
#
# [1 rows x 22 columns]
# Getting information for SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.LINEITEM
#            TABLE_CATALOG TABLE_SCHEMA TABLE_NAME TABLE_OWNER  TABLE_TYPE  \
# 0  SNOWFLAKE_SAMPLE_DATA     TPCH_SF1   LINEITEM        None  BASE TABLE
#
#   IS_TRANSIENT CLUSTERING_KEY ROW_COUNT      BYTES RETENTION_TIME  ...  \
# 0           NO           None   6001215  165228544              1  ...
#
#   USER_DEFINED_TYPE_CATALOG USER_DEFINED_TYPE_SCHEMA USER_DEFINED_TYPE_NAME  \
# 0                      None                     None                   None
#
#   IS_INSERTABLE_INTO IS_TYPED COMMIT_ACTION                          CREATED  \
# 0                YES      YES          None 2021-11-11 13:17:33.269000-08:00
#
#                       LAST_ALTERED AUTO_CLUSTERING_ON  \
# 0 2022-04-16 04:09:08.519000-07:00                 NO
#
#                              COMMENT
# 0  Lineitem data as defined by TPC-H
#
# [1 rows x 22 columns]

# %%
# For each table, get some basic information about the columns in the table
for db, schema, table_name in tables_to_check:
    print(f"Getting column types for {db}.{schema}.{table_name}")
    table_info = get_table_column_types(con, db, schema, table_name)
    display(table_info)
# Out:
# Getting column types for SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.CUSTOMER
#   table_name schema_name   column_name  \
# 0   CUSTOMER    TPCH_SF1     C_CUSTKEY
# 1   CUSTOMER    TPCH_SF1        C_NAME
# 2   CUSTOMER    TPCH_SF1     C_ADDRESS
# 3   CUSTOMER    TPCH_SF1   C_NATIONKEY
# 4   CUSTOMER    TPCH_SF1       C_PHONE
# 5   CUSTOMER    TPCH_SF1     C_ACCTBAL
# 6   CUSTOMER    TPCH_SF1  C_MKTSEGMENT
# 7   CUSTOMER    TPCH_SF1     C_COMMENT
#
#                                            data_type     null? default  \
# 0  {"type":"FIXED","precision":38,"scale":0,"null...  NOT_NULL
# 1  {"type":"TEXT","length":25,"byteLength":100,"n...  NOT_NULL
# 2  {"type":"TEXT","length":40,"byteLength":160,"n...  NOT_NULL
# 3  {"type":"FIXED","precision":38,"scale":0,"null...  NOT_NULL
# 4  {"type":"TEXT","length":15,"byteLength":60,"nu...  NOT_NULL
# 5  {"type":"FIXED","precision":12,"scale":2,"null...  NOT_NULL
# 6  {"type":"TEXT","length":10,"byteLength":40,"nu...      true
# 7  {"type":"TEXT","length":117,"byteLength":468,"...      true
#
#      kind expression comment          database_name autoincrement
# 0  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 1  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 2  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 3  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 4  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 5  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 6  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 7  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# Getting column types for SNOWFLAKE_SAMPLE_DATA.TPCH_SF1.LINEITEM
#    table_name schema_name      column_name  \
# 0    LINEITEM    TPCH_SF1       L_ORDERKEY
# 1    LINEITEM    TPCH_SF1        L_PARTKEY
# 2    LINEITEM    TPCH_SF1        L_SUPPKEY
# 3    LINEITEM    TPCH_SF1     L_LINENUMBER
# 4    LINEITEM    TPCH_SF1       L_QUANTITY
# 5    LINEITEM    TPCH_SF1  L_EXTENDEDPRICE
# 6    LINEITEM    TPCH_SF1       L_DISCOUNT
# 7    LINEITEM    TPCH_SF1            L_TAX
# 8    LINEITEM    TPCH_SF1     L_RETURNFLAG
# 9    LINEITEM    TPCH_SF1     L_LINESTATUS
# 10   LINEITEM    TPCH_SF1       L_SHIPDATE
# 11   LINEITEM    TPCH_SF1     L_COMMITDATE
# 12   LINEITEM    TPCH_SF1    L_RECEIPTDATE
# 13   LINEITEM    TPCH_SF1   L_SHIPINSTRUCT
# 14   LINEITEM    TPCH_SF1       L_SHIPMODE
# 15   LINEITEM    TPCH_SF1        L_COMMENT
#
#                                             data_type     null? default  \
# 0   {"type":"FIXED","precision":38,"scale":0,"null...  NOT_NULL
# 1   {"type":"FIXED","precision":38,"scale":0,"null...  NOT_NULL
# 2   {"type":"FIXED","precision":38,"scale":0,"null...  NOT_NULL
# 3   {"type":"FIXED","precision":38,"scale":0,"null...  NOT_NULL
# 4   {"type":"FIXED","precision":12,"scale":2,"null...  NOT_NULL
# 5   {"type":"FIXED","precision":12,"scale":2,"null...  NOT_NULL
# 6   {"type":"FIXED","precision":12,"scale":2,"null...  NOT_NULL
# 7   {"type":"FIXED","precision":12,"scale":2,"null...  NOT_NULL
# 8   {"type":"TEXT","length":1,"byteLength":4,"null...  NOT_NULL
# 9   {"type":"TEXT","length":1,"byteLength":4,"null...  NOT_NULL
# 10                   {"type":"DATE","nullable":false}  NOT_NULL
# 11                   {"type":"DATE","nullable":false}  NOT_NULL
# 12                   {"type":"DATE","nullable":false}  NOT_NULL
# 13  {"type":"TEXT","length":25,"byteLength":100,"n...  NOT_NULL
# 14  {"type":"TEXT","length":10,"byteLength":40,"nu...  NOT_NULL
# 15  {"type":"TEXT","length":44,"byteLength":176,"n...  NOT_NULL
#
#       kind expression comment          database_name autoincrement
# 0   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 1   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 2   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 3   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 4   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 5   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 6   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 7   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 8   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 9   COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 10  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 11  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 12  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 13  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 14  COLUMN                     SNOWFLAKE_SAMPLE_DATA
# 15  COLUMN                     SNOWFLAKE_SAMPLE_DATA
