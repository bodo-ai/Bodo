# %%
"""Preprocess and query LLMs:
- Install llm package using pip install llm
- Set keys for the model you'd like to use, using llm keys set [MODEL]
"""

import pandas as pd
import time
from dotenv import load_dotenv
import llm

load_dotenv()
MODEL = "gemini-1.5-flash-8b-latest"
model = llm.get_model(MODEL) 

def query_model(prompt):
    """
    Sends a prompt to the AI Suite and returns the response.
    """
    response = model.prompt(prompt) 
    return response.text()

def query_model_all(df):
    """Clean up prompts and query the model for all prompts in the dataframe."""
    t0 = time.time()
    cleaned_prompts = df["prompt"].str.strip().str.lower()
    df["response"] = cleaned_prompts.map(query_model)
    print("Processing time:", time.time() - t0)
    return df


if __name__ == "__main__":
    raw_prompts = [
        " What is the capital of France? ",
        " What is the meaning of life? ",
        " What is the smoothest part of the universe?",
    ]

    # Repeat prompts 10 times for testing purposes
    df = pd.DataFrame({"prompt": raw_prompts*10})
    out_df = query_model_all(df)
    print(out_df)
# Out:
# Processing time: 25.488112211227417
#                                           prompt  \
# 0                What is the capital of France?
# 1                  What is the meaning of life?
# 2    What is the smoothest part of the universe?
# 3                What is the capital of France?
# 4                  What is the meaning of life?
# 5    What is the smoothest part of the universe?
# 6                What is the capital of France?
# 7                  What is the meaning of life?
# 8    What is the smoothest part of the universe?
# 9                What is the capital of France?
# 10                 What is the meaning of life?
# 11   What is the smoothest part of the universe?
# 12               What is the capital of France?
# 13                 What is the meaning of life?
# 14   What is the smoothest part of the universe?
# 15               What is the capital of France?
# 16                 What is the meaning of life?
# 17   What is the smoothest part of the universe?
# 18               What is the capital of France?
# 19                 What is the meaning of life?
# 20   What is the smoothest part of the universe?
# 21               What is the capital of France?
# 22                 What is the meaning of life?
# 23   What is the smoothest part of the universe?
# 24               What is the capital of France?
# 25                 What is the meaning of life?
# 26   What is the smoothest part of the universe?
# 27               What is the capital of France?
# 28                 What is the meaning of life?
# 29   What is the smoothest part of the universe?
#
#                                              response
# 0                                             Paris\n
# 1   There's no single, universally accepted answer...
# 2   The smoothest part of the universe, in terms o...
# 3                                             Paris\n
# 4   There's no single, universally accepted answer...
# 5   The smoothest part of the universe, on the lar...
# 6                                             Paris\n
# 7   There's no single, universally accepted answer...
# 8   The smoothest part of the universe is the **co...
# 9                                             Paris\n
# 10  There's no single, universally accepted answer...
# 11  The smoothest part of the universe, on the lar...
# 12                                            Paris\n
# 13  There's no single, universally accepted answer...
# 14  The smoothest part of the universe, in terms o...
# 15                                            Paris\n
# 16  There's no single, universally accepted answer...
# 17  The smoothest part of the universe, in terms o...
# 18                                            Paris\n
# 19  There's no single, universally accepted answer...
# 20  The smoothest part of the universe, on the lar...
# 21                                            Paris\n
# 22  There's no single, universally accepted answer...
# 23  The smoothest part of the universe, on the lar...
# 24                                            Paris\n
# 25  There's no single, universally accepted answer...
# 26  The smoothest part of the universe, in terms o...
# 27                                            Paris\n
# 28  There's no single, universally accepted answer...
# 29  The smoothest part of the universe, in terms o...

# %%
"""Preprocess and query LLMs, Bodo edition:
- Install llm package using pip install llm
- Set keys for the model you'd like to use, using llm keys set [MODEL]
"""

import pandas as pd
import bodo
import time
from dotenv import load_dotenv
import llm

load_dotenv()
MODEL = "gemini-1.5-flash-8b-latest"
model = llm.get_model(MODEL) 

@bodo.wrap_python(bodo.string_type)
def query_model(prompt):
    """
    Sends a prompt to the AI Suite and returns the response.
    """
    response = model.prompt(prompt) 
    return response.text()

@bodo.jit
def query_model_all(df):
    """Clean up prompts and query the model for all prompts in the dataframe."""
    t0 = time.time()
    cleaned_prompts = df["prompt"].str.strip().str.lower()
    df["response"] = cleaned_prompts.map(query_model)
    print("Processing time:", time.time() - t0)
    return df


if __name__ == "__main__":
    raw_prompts = [
        " What is the capital of France? ",
        " What is the meaning of life? ",
        " What is the smoothest part of the universe?",
    ]

    # Repeat prompts 10 times for testing purposes
    df = pd.DataFrame({"prompt": raw_prompts*10})
    out_df = query_model_all(df)
    print(out_df)
# Out:
# Processing time: 2.664072000000033
#                                           prompt  \
# 0                What is the capital of France?
# 1                  What is the meaning of life?
# 2    What is the smoothest part of the universe?
# 3                What is the capital of France?
# 4                  What is the meaning of life?
# 5    What is the smoothest part of the universe?
# 6                What is the capital of France?
# 7                  What is the meaning of life?
# 8    What is the smoothest part of the universe?
# 9                What is the capital of France?
# 10                 What is the meaning of life?
# 11   What is the smoothest part of the universe?
# 12               What is the capital of France?
# 13                 What is the meaning of life?
# 14   What is the smoothest part of the universe?
# 15               What is the capital of France?
# 16                 What is the meaning of life?
# 17   What is the smoothest part of the universe?
# 18               What is the capital of France?
# 19                 What is the meaning of life?
# 20   What is the smoothest part of the universe?
# 21               What is the capital of France?
# 22                 What is the meaning of life?
# 23   What is the smoothest part of the universe?
# 24               What is the capital of France?
# 25                 What is the meaning of life?
# 26   What is the smoothest part of the universe?
# 27               What is the capital of France?
# 28                 What is the meaning of life?
# 29   What is the smoothest part of the universe?
#
#                                              response
# 0                                              Paris
#
# 1   There's no single, universally accepted answer...
# 2   The smoothest part of the universe is the **Co...
# 3                                              Paris
#
# 4   There's no single, universally accepted answer...
# 5   The smoothest part of the universe is generall...
# 6                                              Paris
#
# 7   There's no single, universally accepted answer...
# 8   The smoothest part of the universe, in terms o...
# 9                                              Paris
#
# 10  There's no single, universally accepted answer...
# 11  The smoothest part of the universe, in terms o...
# 12                                             Paris
#
# 13  There's no single, universally accepted answer...
# 14  The smoothest part of the universe, on the lar...
# 15                                             Paris
#
# 16  There's no single, universally accepted answer...
# 17  The smoothest part of the universe is consider...
# 18                                             Paris
#
# 19  There's no single, universally accepted answer...
# 20  The smoothest part of the universe, in terms o...
# 21                                             Paris
#
# 22  There's no single, universally accepted answer...
# 23  The smoothest part of the universe, as far as ...
# 24                                             Paris
#
# 25  There's no single, universally accepted answer...
# 26  The smoothest part of the universe, in terms o...
# 27                                             Paris
#
# 28  There's no single, universally accepted answer...
# 29  The smoothest part of the universe is the **Co...
